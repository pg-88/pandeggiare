# %%
import pandas as pd
import os

# %% [markdown]
# ### DataFrame da file Excel

# %%
df = pd.DataFrame()

# try:
#     df = pd.read_excel("utilities/MOCK_DATA.xlsx")
# except Exception as err: 
#    print(err)
# df
# Out:
#        id first_name   last_name                             email  \
# 0       1      Dania      Eusden              deusden0@comcast.net
# 1       2       Hill      Braine               hbraine1@oakley.com
# 2       3   Prentice  Swinnerton            pswinnerton2@google.fr
# 3       4     Dorian        Wein           dwein3@chronoengine.com
# 4       5    Cristal     Duckitt                 cduckitt4@nyu.edu
# ..    ...        ...         ...                               ...
# 995   996   Hendrika     Gitting           hgittingrn@edublogs.org
# 996   997     Stinky  Vedishchev          svedishchevro@uol.com.br
# 997   998  Kendricks      Cosins               kcosinsrp@slate.com
# 998   999    Magdaia   Geistbeck  mgeistbeckrq@creativecommons.org
# 999  1000      Jason    Bernardi             jbernardirr@wikia.com
#
#           gender       ip_address
# 0         Female     1.93.145.241
# 1           Male   138.252.125.93
# 2           Male  113.244.169.150
# ...

# %% [markdown]
# Per questioni di formattazione ci potrebbero essere delle righe in testa al foglio che non contengono dati.
# In questo caso le colonne del df avranno nome "Unnamed"

# %%
try:
    df = pd.read_excel("utilities/empty_rows.xlsx")
except Exception as err: 
   print(err)
df
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2                        Unnamed: 3  \
# 0            id  first_name   last_name                             email
# 1           NaN         NaN         NaN                               NaN
# 2             1       Dania      Eusden              deusden0@comcast.net
# 3             2        Hill      Braine               hbraine1@oakley.com
# 4             3    Prentice  Swinnerton            pswinnerton2@google.fr
# ...         ...         ...         ...                               ...
# 997         996    Hendrika     Gitting           hgittingrn@edublogs.org
# 998         997      Stinky  Vedishchev          svedishchevro@uol.com.br
# 999         998   Kendricks      Cosins               kcosinsrp@slate.com
# 1000        999     Magdaia   Geistbeck  mgeistbeckrq@creativecommons.org
# 1001       1000       Jason    Bernardi             jbernardirr@wikia.com
#
#      Unnamed: 4       Unnamed: 5
# 0        gender       ip_address
# ...

# %% [markdown]
# Per rinominarle uso il metodo rename creando un dict da passare all'argomento columns del metodo.
# Quindi:
#
# 1) recupero il nome attuale delle colonne
# 2) recupe i nomi corretti delle colonne
# 3) creo un dictionary
# 4) uso il metodo rename

# %%
# colonne attuali 
col = df.columns
nuovi_nomi = df.iloc[0]
d = {old: new for old, new in zip(col, nuovi_nomi)}
df.rename(columns=d, inplace=True)
df
# Out:
#         id  first_name   last_name                             email  \
# 0       id  first_name   last_name                             email
# 1      NaN         NaN         NaN                               NaN
# 2        1       Dania      Eusden              deusden0@comcast.net
# 3        2        Hill      Braine               hbraine1@oakley.com
# 4        3    Prentice  Swinnerton            pswinnerton2@google.fr
# ...    ...         ...         ...                               ...
# 997    996    Hendrika     Gitting           hgittingrn@edublogs.org
# 998    997      Stinky  Vedishchev          svedishchevro@uol.com.br
# 999    998   Kendricks      Cosins               kcosinsrp@slate.com
# 1000   999     Magdaia   Geistbeck  mgeistbeckrq@creativecommons.org
# 1001  1000       Jason    Bernardi             jbernardirr@wikia.com
#
#         gender       ip_address
# 0       gender       ip_address
# 1          NaN              NaN
# 2       Female     1.93.145.241
# ...
